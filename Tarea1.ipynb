# %% [markdown]
# <a href="https://colab.research.google.com/github/1701211009-a11y/introduccion_DS_UNJFSC/blob/main/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_cancer = pd.read_csv('https://raw.githubusercontent.com/1701211009-a11y/introduccion_DS_UNJFSC/refs/heads/main/Datasets/cancer.csv')
data_cancer.tail()
# Out:
#      Unnamed: 0  Age Number.of.sexual.partners First.sexual.intercourse  \
# 853         854   34                       3.0                     18.0
# 854         855   32                       2.0                     19.0
# 855         856   25                       2.0                     17.0
# 856         857   33                       2.0                     24.0
# 857         858   29                       2.0                     20.0
#
#     Num.of.pregnancies Smokes Smokes..years. Smokes..packs.year.  \
# 853                0.0    0.0            0.0                 0.0
# 854                1.0    0.0            0.0                 0.0
# 855                0.0    0.0            0.0                 0.0
# 856                2.0    0.0            0.0                 0.0
# 857                1.0    0.0            0.0                 0.0
#
#     Hormonal.Contraceptives Hormonal.Contraceptives..years.  ...  \
# 853                     0.0                             0.0  ...
# ...
